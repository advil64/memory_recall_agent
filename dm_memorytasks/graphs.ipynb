# %%
import pandas as pd

# %%
# spot_diff_train = pd.read_csv('./sb3_log_2/progress.csv')
# spot_diff_train.head()

invis_builds = pd.read_csv('./invis_builds/progress.csv')
invis_builds.tail()
# Out:
#        time/time_elapsed  train/n_updates  train/explained_variance  \
# 85727              43178           342911              0.000000e+00
# 85728              43179           342915              0.000000e+00
# 85729              43179           342919             -1.192093e-07
# 85730              43179           342923              0.000000e+00
# 85731              43180           342927              0.000000e+00
#
#        train/value_loss  train/entropy_loss  time/total_timesteps  time/fps  \
# 85727      2.392362e-10           -0.045382               1714560        39
# 85728      4.393932e-10           -0.045383               1714580        39
# 85729      9.181237e-10           -0.045383               1714600        39
# 85730      2.097801e-09           -0.045384               1714620        39
# 85731      4.779217e-09           -0.045386               1714640        39
#
#        train/policy_loss  train/learning_rate  time/iterations  \
# ...

# %%
import plotly.express as px
fig = px.line(invis_builds[invis_builds['time/total_timesteps'] < 800000], x='time/total_timesteps', y='train/entropy_loss', title='Spot the Difference Training')
fig.show()

# %%
fig = px.scatter(spot_diff_train[spot_diff_train['time/total_timesteps'] < 1000], x='time/total_timesteps', y='train/entropy_loss', title='Spot the Difference Training First 1k Timesteps')
fig.show()

# %%
# !pip3 install -U kaleido
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 14.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
# fig.write_image('mean_rew_spot_diff.png', scale=5)
fig.write_image('entropy_loss_invis_builds.png', scale=5)
