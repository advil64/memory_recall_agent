# %%
import pandas as pd

# %%
spot_diff_train = pd.read_csv('./sb3_log_2/progress.csv')
spot_diff_train.head()
# Out:
#    train/policy_loss  time/time_elapsed  time/total_timesteps  time/fps  \
# 0           0.166414                  3                    20         6
# 1          -0.127876                  5                    40         7
# 2           0.133080                  6                    60         9
# 3           0.083753                  7                    80        11
# 4          -0.002996                  7                   100        13
#
#    train/entropy_loss  time/iterations  train/value_loss  train/n_updates  \
# 0           -2.006250                4          0.014647                3
# 1           -1.965070                8          0.005446                7
# 2           -1.460955               12          0.011820               11
# 3           -2.006391               16          0.003662               15
# 4           -2.077090               20          0.000003               19
#
#    train/learning_rate  train/explained_variance  rollout/ep_rew_mean  \
# ...

# %%
import plotly.express as px
fig = px.scatter(x=spot_diff_train['time/total_timesteps'], y=spot_diff_train['rollout/ep_rew_mean'])
fig.show()
